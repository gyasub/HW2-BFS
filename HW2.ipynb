# %%
import networkx as nx
import matplotlib.pyplot as plt
import plotly.graph_objects as go

# %%
graph_instance = nx.read_adjlist('/Users/gyasubajracharya/Desktop/UCSF/Algorithms/HW2-BFS/data/tiny_network.adjlist')

list_of_nodes = list(graph_instance.nodes)
print(list_of_nodes)


#first_node = next(graph_instance.nodes())
# Out:
# ['31806696;Luke', 'Gilbert', '31486345;Michael', 'Keiser;Marina', 'Sirota', '29700475;Michael', 'Keiser;Nevan', 'Krogan', '33765435;Marina', '32025019;Atul', 'Butte;Hani', 'Goodarzi', 'Nevan', 'Krogan;34272374;32353859;30944313', 'Neil', 'Risch;29700475', '30944313;Hani', 'Goodarzi;Nevan', 'Krogan;Marina', '33483487;Luke', 'Gilbert;Martin', 'Kampmann', '30727954;Michael', 'McManus', '34272374;Martin', 'Lani', 'Wu;32042149;32036252;31806696;30727954', 'Atul', 'Butte;33765435;33242416;31395880;30944313', 'Marina', 'Sirota;31486345', '32042149;Hani', '32790644;Steven', 'Altschuler;Lani', 'Wu', 'Michael', 'McManus;32025019;31540829;30727954;29700475', '32036252;Steven', 'Martin', 'Kampmann;33483487;32790644;31806696;31626775;31540829', '33242416;Atul', 'Butte', 'Charles', 'Chiu;33242416', '31395880;Steven', '31626775;Luke', 'Kampmann;Neil', 'Risch', '31540829;Luke', 'Gilbert;Nevan', 'Luke', 'Gilbert;33483487;31806696;31626775;31540829', 'Keiser;33232663', 'Hani', 'Goodarzi;33232663', 'St
# ...

# %%
pos = nx.spring_layout(G)

nx.draw(graph_instance, pos, with_labels=True, font_size=8, node_size=500, node_color='skyblue', font_color='black', font_weight='bold')

nx.draw_networkx_edges(graph_instance, pos, width=1, alpha=0.7, edge_color='gray')

plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Create a directed graph
G = nx.DiGraph()

# Add nodes
G.add_nodes_from([1, 2, 3, 4, 5])

# Add edges
G.add_edges_from([(1, 2), (2, 3), (3, 4), (4, 5), (5, 1)])

# Draw the graph
pos = nx.circular_layout(G)
nx.draw(G, pos, with_labels=True, arrows=True, connectionstyle='arc3,rad=0.1')
plt.show()
